# %%
import pandas as pd
table = pd.DataFrame({'edro': [32.94, 30.10, 33.97, 31.75, 38.67, 37.77, 40.63], 'apple': [12.96, 3.06, 3.36, 2.10, 4.66, 2.98, 1.94],
                      'sr': [12.79, 21.68, 0, 16.53, 0, 11.88, 12.24], 'kprf': [11.24, 18.43, 20.88, 22.69, 25.90, 24.56, 20.28],
                      'nl': [9.9, 6.03, 11.01, 8.65, 9.51, 0, 5.84], 'kr': [4.92, 0, 0, 0, 0, 0, 0],
                      'ldpr': [4.2, 4.83, 6.45, 7.10, 10.83, 9.47, 6.59], 'pp': [4.04, 4.71, 7.17, 0, 0, 0, 2.86],
                      'rod': [1.63, 2.55, 2.05, 2.31, 2.67, 7.20, 0.99], 'rpss': [0, 2.32, 6.05, 1.79, 0, 0, 0],
                      'rost': [0, 0, 2.61, 0, 0 ,0 ,0]})
table
# Out:
#     edro  apple     sr   kprf     nl    kr   ldpr    pp   rod  rpss  rost
# 0  32.94  12.96  12.79  11.24   9.90  4.92   4.20  4.04  1.63  0.00  0.00
# 1  30.10   3.06  21.68  18.43   6.03  0.00   4.83  4.71  2.55  2.32  0.00
# 2  33.97   3.36   0.00  20.88  11.01  0.00   6.45  7.17  2.05  6.05  2.61
# 3  31.75   2.10  16.53  22.69   8.65  0.00   7.10  0.00  2.31  1.79  0.00
# 4  38.67   4.66   0.00  25.90   9.51  0.00  10.83  0.00  2.67  0.00  0.00
# 5  37.77   2.98  11.88  24.56   0.00  0.00   9.47  0.00  7.20  0.00  0.00
# 6  40.63   1.94  12.24  20.28   5.84  0.00   6.59  2.86  0.99  0.00  0.00

# %%
table['opposition_coefficient'] = 100 - (table['nl'] + table['rost'] + table['ldpr'] + table['apple'] + table['kr'] + table['pp'] - table['edro'] - table['sr'] - table['kprf'] - table['rod'] - table['rpss']) * -1
table
# Out:
#     edro  apple     sr   kprf     nl    kr   ldpr    pp   rod  rpss  rost  \
# 0  32.94  12.96  12.79  11.24   9.90  4.92   4.20  4.04  1.63  0.00  0.00
# 1  30.10   3.06  21.68  18.43   6.03  0.00   4.83  4.71  2.55  2.32  0.00
# 2  33.97   3.36   0.00  20.88  11.01  0.00   6.45  7.17  2.05  6.05  2.61
# 3  31.75   2.10  16.53  22.69   8.65  0.00   7.10  0.00  2.31  1.79  0.00
# 4  38.67   4.66   0.00  25.90   9.51  0.00  10.83  0.00  2.67  0.00  0.00
# 5  37.77   2.98  11.88  24.56   0.00  0.00   9.47  0.00  7.20  0.00  0.00
# 6  40.63   1.94  12.24  20.28   5.84  0.00   6.59  2.86  0.99  0.00  0.00
#
#    opposition_coefficient
# 0                   77.42
# 1                   43.55
# 2                   67.65
# 3                   42.78
# 4                   57.76
# 5                   31.04
# 6                   43.09

# %%
import matplotlib.pyplot as plt
table['opposition_coefficient'].plot(kind = 'bar', xlabel = 'Избирательный округ', ylabel = 'коэффициент электоральной близости')
plt.title('Велиина коэффициента электоральной близости по округам')
plt.savefig('pfpfp.png')
